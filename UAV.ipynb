# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os

project_path = '/content/drive/MyDrive/MultiUAV_Baseline_code_and_submissi'

if project_path not in sys.path:
    sys.path.append(project_path)

os.chdir(project_path)

print(f"현재 작업 경로: {os.getcwd()}")
print("시스템 경로에 프로젝트 폴더 추가 완료")

from utils_ds.parser import get_config
from utils_ds.draw import draw_boxes
from deep_sort import build_tracker

print("모듈 불러오기 성공")
# Out:
# 현재 작업 경로: /content/drive/MyDrive/MultiUAV_Baseline_code_and_submissi
# 시스템 경로에 프로젝트 폴더 추가 완료!
# 모듈 불러오기 성공!

# %%
from yolov5.utils.general import check_img_size, non_max_suppression, scale_coords, xyxy2xywh
from yolov5.utils.torch_utils import select_device, time_synchronized
from yolov5.utils.datasets import letterbox

from utils_ds.parser import get_config
from utils_ds.draw import draw_boxes
from deep_sort import build_tracker

import argparse
import os
import time
import numpy as np
import warnings
import cv2
import torch
import torch.backends.cudnn as cudnn
